# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style = 'white')

pd.set_option('display.max_row',100)
pd.set_option('display.max_column',100)
# %matplotlib inline

# %%
# !ls
# Out:
# OA1.ipynb              data.csv               test_cases_fif29c6fqrh
# OA2.ipynb              onsite.ipynb

# %%
data = pd.read_csv('data.csv')
data.head()
# Out:
#    Unnamed: 0  X1  X2    X3     X4   X5  X6  X7    X8    X9    X10  X11  X12  \
# 0           0   1  60  65.0   8450  NaN   7   5  2003  2003  196.0  706    0
# 1           1   2  20  80.0   9600  NaN   6   8  1976  1976    0.0  978    0
# 2           2   3  60  68.0  11250  NaN   7   5  2001  2002  162.0  486    0
# 3           3   4  70  60.0   9550  NaN   7   5  1915  1970    0.0  216    0
# 4           4   5  60  84.0  14260  NaN   8   5  2000  2000  350.0  655    0
#
#    X13   X14   X15   X16  X17   X18  X19  X20  X21  X22  X23  X24  X25  X26  \
# 0  150   856   856   854    0  1710    1    0    2    1    3    1    8    0
# 1  284  1262  1262     0    0  1262    0    1    2    0    3    1    6    1
# 2  434   920   920   866    0  1786    1    0    2    1    3    1    6    1
# 3  540   756   961   756    0  1717    1    0    1    0    3    1    7    1
# 4  490  1145  1145  1053    0  2198    1    0    2    1    4    1    9    1
#
# ...

# %%
data = data.iloc[:,2:]

# %%
data.describe()
# Out:
#                 X2           X3             X4           X6           X7  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#                 X8           X9          X10          X11          X12  \
# count  1460.000000  1460.000000  1452.000000  1460.000000  1460.000000
# mean   1971.267808  1984.865753   103.685262   443.639726    46.549315
# std      30.202904    20.645407   181.066207   456.098091   161.319273
# ...

# %%
length = data.shape[0]
length
# Out:
# 1460

# %%
data['X3'].describe()
# Out:
# count    1201.000000
# mean       70.049958
# std        24.284752
# min        21.000000
# 25%        59.000000
# 50%        69.000000
# 75%        80.000000
# max       313.000000
# Name: X3, dtype: float64

# %%
data.isnull().sum()
# Out:
# X2        0
# X3      259
# X4        0
# X5     1369
# X6        0
# X7        0
# X8        0
# X9        0
# X10       8
# X11       0
# X12       0
# X13       0
# X14       0
# X15       0
# X16       0
# X17       0
# X18       0
# X19       0
# X20       0
# X21       0
# X22       0
# X23       0
# X24       0
# X25       0
# X26       0
# X27      81
# X28       0
# X29       0
# X30       0
# X31       0
# X32       0
# X33       0
# X34       0
# X35       0
# X36    1453
# X37    1179
# X38    1406
# X39       0
# X40       0
# X41       0
# X42       0
# dtype: int64

# %%
list(data.isnull().sum() < length * 0.2)
# Out:
# [True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True]

# %%
data1 = data.iloc[:,list(data.isnull().sum() < length * 0.2)]

# %%
data1.duplicated(keep='first').sum()
# Out:
# 0

# %%
data1['X42'].hist(cumulative=False, density=1, bins=100)

# %%
data1['X42'].mean()
# Out:
# 180921.19589041095

# %%
data1['X42'].std()
# Out:
# 79442.50288288663

# %%
data1['X42'].mean() + 3 * data1['X42'].std()
# Out:
# 419248.70453907084

# %%
# detect outliers
data2 = data1[np.abs(data1['X42']-data1['X42'].mean()) <= (3*data1['X42'].std())]

# %%
data3 = (data2 - data2.mean())/data2.std()

# %%
data3.describe()
# Out:
#                  X2            X3            X4            X6            X7  \
# count  1.438000e+03  1.181000e+03  1.438000e+03  1.438000e+03  1.438000e+03
# mean  -5.867660e-17  3.670975e-17 -6.875681e-17 -2.237431e-16  1.778827e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -8.714269e-01 -2.021343e+00 -9.151358e-01 -3.785984e+00 -4.106351e+00
# 25%   -8.714269e-01 -4.442872e-01 -2.917284e-01 -7.880517e-01 -5.205410e-01
# 50%   -1.660445e-01 -2.927242e-02 -1.006842e-01 -3.856867e-02 -5.205410e-01
# 75%    3.042105e-01  4.272438e-01  1.045375e-01  7.109144e-01  3.759116e-01
# max    3.125740e+00  1.009709e+01  2.059695e+01  2.959364e+00  3.065269e+00
#
#                  X8            X9           X10           X11           X12  \
# count  1.438000e+03  1.438000e+03  1.431000e+03  1.438000e+03  1.438000e+03
# mean  -6.947001e-16  1.308565e-15 -5.218281e-16 -1.080885e-17  2.098460e-16
# ...

# %%
data4 = data3.fillna(0)

# %%
data4.shape
# Out:
# (1438, 37)

# %%
data4.corr()
# Out:
#            X2        X3        X4        X6        X7        X8        X9  \
# X2   1.000000 -0.361317 -0.140439  0.042338 -0.062877  0.033662  0.045019
# X3  -0.361317  1.000000  0.308465  0.212715 -0.050615  0.109271  0.073616
# X4  -0.140439  0.308465  1.000000  0.085464 -0.003491  0.005644  0.004242
# X6   0.042338  0.212715  0.085464  1.000000 -0.086951  0.572662  0.545814
# X7  -0.062877 -0.050615 -0.003491 -0.086951  1.000000 -0.368781  0.080811
# X8   0.033662  0.109271  0.005644  0.572662 -0.368781  1.000000  0.588600
# X9   0.045019  0.073616  0.004242  0.545814  0.080811  0.588600  1.000000
# X10  0.030266  0.169245  0.077103  0.374851 -0.122877  0.304365  0.161688
# X11 -0.060450  0.203046  0.203077  0.200271 -0.033936  0.232008  0.110204
# X12 -0.065155  0.043973  0.115071 -0.058361  0.040403 -0.048607 -0.066971
# X13 -0.141782  0.118701 -0.004205  0.306280 -0.139043  0.147669  0.178522
# X14 -0.236166  0.353976  0.253482  0.506858 -0.164819  0.378959  0.275888
# ...

# %%
plt.matshow(data4.corr())

# %%
matrix =

# %%
for i in range(len)

# %%
data
# Out:
#       Unnamed: 0    X1   X2     X3     X4    X5  X6  X7    X8    X9    X10  \
# 0              0     1   60   65.0   8450   NaN   7   5  2003  2003  196.0
# 1              1     2   20   80.0   9600   NaN   6   8  1976  1976    0.0
# 2              2     3   60   68.0  11250   NaN   7   5  2001  2002  162.0
# 3              3     4   70   60.0   9550   NaN   7   5  1915  1970    0.0
# 4              4     5   60   84.0  14260   NaN   8   5  2000  2000  350.0
# 5              5     6   50   85.0  14115   NaN   5   5  1993  1995    0.0
# 6              6     7   20   75.0  10084   NaN   8   5  2004  2005  186.0
# 7              7     8   60    NaN  10382   NaN   7   6  1973  1973  240.0
# 8              8     9   50   51.0   6120   NaN   7   5  1931  1950    0.0
# 9              9    10  190   50.0   7420   NaN   5   6  1939  1950    0.0
# 10            10    11   20   70.0  11200   NaN   5   5  1965  1965    0.0
# ...

# %% [markdown]
# ### Fitting the model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X = data4.iloc[:,:-1]
y = data4.iloc[:, -1]

# %%
X.shape
# Out:
# (1438, 38)

# %%
y.shape
# Out:
# (1438,)

# %%
X = np.asarray(X)
y = np.asarray(y)[:,np.newaxis]

# %%
X.shape
# Out:
# (1438, 38)

# %%
y.shape
# Out:
# (1438, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=0.2)
# Out:
# /Users/kevin/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
# Turn up tolerance for faster convergence
clf = LinearRegression()
clf.fit(X_train, y_train)
score = clf.score(X_test, y_test)

from sklearn.metrics import mean_squared_error
>>> y_true = [3, -0.5, 2, 7]
>>> y_pred = [2.5, 0.0, 2, 8]
>>> mean_squared_error(y_true, y_pred)

from sklearn.ensemble import RandomForestRegressor

regr = RandomForestRegressor(max_depth=2, random_state=0,
...                              n_estimators=100)
# Out:
# /Users/kevin/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-f409ec8bd599> in <module>()
#       3                          multi_class='multinomial',
#       4                          penalty='l1', solver='saga', tol=0.1)
# ----> 5 clf.fit(X_train, y_train)
#       6 sparsity = np.mean(clf.coef_ == 0) * 100
#       7 score = clf.score(X_test, y_test)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1215         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype,
#    1216                          order="C")
# ...
